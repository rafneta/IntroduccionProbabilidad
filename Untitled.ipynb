# %%
from ProgramasProba.Proba import *

# %%
x=[1,2,3]
plt.plot(x,x)
plt.show()

def f(x):
    return np.piecewise(x,[x<-1,(-1<x) & (x<1),x>1],[0,lambda x:(3.0/2.0)*np.power(x,2),0])

gfdvac((-2,2),f)
gFdfvac((-1.1,1.1),f)
