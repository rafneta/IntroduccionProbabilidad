# %% [markdown]
# # Estadística inferencial

# %%
import pandas as pd # importamos el modulo
import numpy as np
import matplotlib.pyplot as plt
from __future__ import print_function # utilizar print como funcion 
from scipy import stats # importando scipy.stats
from ProgramasProba.Proba import *

# %%
vcnormal = stats.norm(loc=3, scale=2)
Xnormal = vcnormal.rvs(size=100)
df = pd.DataFrame({'Datos-norm':Xnormal})

# %%
fig, (ax1,ax2)=plt.subplots(1,2,figsize=(16,5))
x=np.linspace(-1,7,num=300)
Y=np.zeros(100)
ax1.plot(x,vcnormal.pdf(x))
ax1.plot(Xnormal,Y,'ob')
ax2.scatter(x=np.linspace(0,99,num=100), y=df['Datos-norm'],color='b') 
plt.show()

# %%
df.hist(color='b', alpha=0.5, bins=15, density=True);

# %% [markdown]
# # Intervalos de confanza para varianza de la población conocida

# %%
def intervalosVC(numero_de_muestras= 100,tam_muestra = 1000,alpha=0.05, bandera=False):
    intervalos = []
    medias = []
    contador=0
    for num in range(numero_de_muestras):
        muestra_media = stats.norm.rvs(size=tam_muestra,loc=3,scale=2).mean()
        medias.append(muestra_media)
        z_alpha = stats.norm.ppf(q = 1-alpha/2)  # el valor z alpha/2         
        des_pobla = 2  # desviacion de la poblacion
        margen_de_error = z_alpha * (des_pobla/np.sqrt(tam_muestra))
        intervalo_confianza = (muestra_media - margen_de_error,
                           muestra_media + margen_de_error)
        if (3>intervalo_confianza[0] and 3<intervalo_confianza[1]):
            contador=contador+1
        intervalos.append(intervalo_confianza)
    
    if bandera==True:
        return contador
    
    plt.figure(figsize=(16,9))
    plt.errorbar(x=np.arange(1, numero_de_muestras + 1, 1), 
             y=medias, 
             yerr=[(sup-inf)/2 for inf, sup in intervalos],
            fmt='ro',label="Intervalos de confianza")
    plt.xlabel('Numero de muestras (tamano de muestra %d)'%tam_muestra,fontsize=20)
    plt.ylabel(r'$\bar{X}$',fontsize=20)
    plt.hlines(xmin=0, xmax=numero_de_muestras+1,
           y=3, 
           linewidth=2.0,
           color="blue",label="Media de la poblacion")
    plt.title("Intervalos de confianza para %d muestras"%numero_de_muestras,fontsize=20)
    plt.legend(loc="best",fontsize=15)
    plt.show()
intervalosVC()

# %% [markdown]
# Se puede pensar ahora en lo siguiente, consideremos un ensayo beenoulli, en donde la probabilidad d éxito es de $p=0.95$, en este caso la porbabilidad de que la media se encuentre en el intervalo de confianza, tomemos n=100 ensayos Bernoulli independientes, entonces si se quieren contar el número de éxitos se tiene que
#
# $$X \sim bin(100,0.95)$$
#
# calculamos la probabilidad para $95$ éxitos o menos, esto es, $P(X\leq95)$

# %%
vdbinomial=stats.binom(n=100,p=0.95)
F=vdbinomial.cdf
print("La probabilidad de tener 95 éxitos o menos es",F(95))
print("El valor esperado de la VA es",vdbinomial.mean())
# Out:
# La probabilidad de tener 95 éxitos o menos es 0.5640186993142893
# El valor esperado de la VA es 95.0

# %% [markdown]
# Ahora realicemos el experimeento 1000 veces y calculemos la frecuencia relativa de éxito y el promedio de la muestra..

# %%
intervalosVC(bandera=True)
# Out:
# 94

# %%
contador=0
acumulador=0
for i in range(0,9999):
    valor=intervalosVC(bandera=True)
    if(valor<=95):
        contador=contador+1
    acumulador=valor+acumulador
print("Repitiendo el experimento la frecuencia relativa de observar 95 éxito o menos", contador/10000.0)
print("El promedio de la muestra", acumulador/10000)
# Out:
# Repitiendo el experimento la frecuencia relativa de observar 95 éxito o menos 0.5556
# El promedio de la muestra 95

# %%
# Ejemplo para media y varianza desconocida
datos=[9.8, 10.2, 10.4, 9.8, 10.0, 10.2, 9.6]
df=pd.DataFrame({'Datos':datos})
print("Media de los datos", df.mean())
print("Variansa de los datos",df.var())
print("Desviacion estandar de los datos",np.sqrt(df.var()),df.std())
# Out:
# Media de los datos Datos    10.0
# dtype: float64
# Variansa de los datos Datos    0.08
# dtype: float64
# Desviacion estandar de los datos Datos    0.282843
# dtype: float64 Datos    0.282843
# dtype: float64

# %%
#Pruba de Hipotesis
vdbinomial=stats.binom(n=20,p=0.25)
F=vdbinomial.cdf
print(1-F(8))
# Out:
# 0.04092516770651855

# %%
from IPython.core.display import HTML
css_file = 'Varios/css/estilo1.css'
HTML(open(css_file, "r").read())
# Out:
# <style>
# .def {
#     border-left: 5px solid;
#     /*border-style:solid;
#     border-width:4px;
#     /*-webkit-border-radius:15px;
# 	border-radius: 15px;*/
#     border-color:rgba(102,194,163,0.9);/**  #366272;#CD853F;/**rgba(112, 156, 169, 0.66);*/
#     /*background: #366272;rgba(54, 98, 114, 0.9);/*#366272;*/
# 	/*border-top-left-radius:10%;*/
# 	color:rgba(102,194,163,0.9);
# 	font-size: 1em;
# 	/*box-shadow: 10px 10px 10px #2178a3;*/
# 	/*overflow:scroll;*/
# 	padding: 2% 4% 2% 4%;
# 	box-sizing: border-box;
# 	width:80%;
#     margin-left:auto;
#     margin-right:auto;
#     margin-bottom:2%;
#     margin-top:2%;
#     background:rgba(102,194,163,0.02);/*1(0.40000000596046448, 0.7607843279838562, 0.64705884456634521)*/
# }
#
# .laboratorio {
#     border-left: 5px solid;
#     /*border-width:4px;*/
#     /*-webkit-border-radius:15px;
# 	border-radius: 15px;*/
#     border-color: rgba(249,140,97,0.9);/*#CD853F ; #366272*#CD853F;/**rgba(112, 156, 169, 0.66);*/
#     /*background: #366272;rgba(54, 98, 114, 0.9);/*#366272;*/
# 	/*border-top-left-radius:10%;*/
# 	color:rgba(249,140,97,0.9);
# 	font-size: 1em;
# 	/*box-shadow: 10px 10px 10px #2178a3;*/
# 	/*overflow:scroll;*/
# 	padding: 2% 4% 2% 4%;
# 	box-sizing: border-box;
# 	width:100%;
#     margin-left:auto;
#     margin-right:auto;
#     margin-bottom:2%;
#     margin-top:2%;
#     background:rgba(249,140,97,0.02) /*2(0.98131487965583808, 0.55538641635109398, 0.38740485135246722)*/;
# }
#
#  ul.nobullet{
#  font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 110%; /*cambo de 130 a 100*/
#     font-weight: 400;
#     list-style-type: none;
#
#     }
#
#
# .algoritmo  li strong {
# color:rgba(140,158,201,0.9);
# }
#
# .laboratorio h3 {
# color:rgba(249,140,97,0.9);
# }
#
# .text_cell_render .laboratorio h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     margin-top: 2em;
#     margin-bottom: 1.5em;
#     font-style: regular;
#     color:rgba(249,140,97,0.9);
# }
#
# }
#
#
#  ul.libro{
#  font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 110%; /*cambo de 130 a 100*/
#     font-weight: 400;
#
#     }
#
# .algoritmo{
#     border-left: 5px solid;
#     /*border-width:4px;*/
#     /*-webkit-border-radius:15px;
# 	border-radius: 15px;*/
#     border-color:rgba(140,158,201,0.9);/**  #366272;#CD853F;/**r
# gba(112, 156, 169, 0.66);*/
#     /*background: #366272;rgba(54, 98, 114, 0.9);/*#366272;*/
# 	/*border-top-left-radius:10%;*/
# 	color:rgba(140,158,201,0.9);
# 	font-size: 1em;
# 	/*box-shadow: 10px 10px 10px #2178a3;*/
# 	/*overflow:scroll;*/
# 	padding: 2% 4% 2% 4%;
# 	box-sizing: border-box;
# 	width:95%;
#     margin-left:auto;
#     margin-right:auto;
#     margin-bottom:2%;
#     margin-top:2%;
#     background:rgba(140,158,201,0.02);/*3(0.55432528607985565, 0.62711267120697922, 0.79595541393055635)*/
# }
#
#
#
#
# .text_cell_render p {
# 	font-size: 1.2em;
# 	line-height: 1.6;
# 	font-weight: 300;
# 	text-align: justify;
#     color: black;
# }
#
# div pre
# {
#     color: red;
#     padding: 0.5em;
#     /*margin-left:1em;
#     margin-top: 1em;*/
#     margin-left:auto;
#     margin-right:auto;
#     }
#
#
# .polaroid {
#   width: 80%;
#   background-color: white;
#   /*box-shadow: 0px 0px 1px 0px rgba(0, 0, 0, 0.2);*/
#   margin-bottom: 25px;/*25x*/
#     margin-left:auto;
#     margin-right:auto;
#     margin-top:2%;
# }
#
# .despolaroid p{
#   text-align: center;
#   padding: 10px 20px;/*10px 20px*/
#     margin-left:auto;
#     margin-right:auto;
#     font-size: 0.8em;
# 	line-height: 1;
# 	font-weight: 200;
#
# }
#
#
#
#  img {
#     /*display: block;
#     margin: auto;*/
#     border-bottom: 4px solid #ddd;
#     }
#
# .MathJax a:hover, .MathJax a:active {
#   color: green;
#   text-decoration: none; //underline ! important;
# }
#
# .MathJax a:link{
#   color: blue;
#   text-decoration: none; //underline ! important;
# }
#
#
#
# .projects-button {
#   padding: 0.75em 1.25em;
#   background-color: whitesmoke;
#   opacity: 0.9;
#   width: 10em;
#   color: black;
# }
#
# .projects {
#   margin: 1em 0;
# }
#
# .skillset {
#   display: flex;
#   justify-content: space-between;
#   flex-wrap: wrap;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 35pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
#
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 20pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
#     font-size: 12pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 12pt;
#     /*text-align: center;*/
#     margin-top: 2em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 10pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
#
# /*cite:before {content: " : "}
# cite {font: bold 20px Georgia, "Times New Roman", Times, serif ; text-transform:capitalize; }
#
# blockquote {margin: 1em; padding: 1em; font:Geneva, Arial, Helvetica, sans-serif 14px;}  */
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
# });
# </script>
#
# <script src='https://code.jquery.com/jquery-3.1.0.min.js'></script>
# <script src='../js/main.js'></script>
